# %% [markdown]
# <div align="center">
#   <h1><b>Penyisihan Datavidia 9</b></h1>
#   <p><b>Supercalifragilisticexpialidocious</b></p>
#   <span style="font-size: 12px;">Author: <a href="https://github.com/ChristellaCindy">Christella Cindy</a>, <a href="https://github.com/Frederickkrisna">Frederick Krisna</a>, and <a href="https://github.com/williamtheodoruswijaya">William Theodorus</a></span>
# </div>
# <hr>

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from pmdarima import auto_arima
from statsmodels.tsa.stattools import adfuller
from scipy import stats
from statsmodels.tsa.arima.model import ARIMA

color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# - `Evaluation`

# %%
def mape(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    """
    Calculate the Mean Absolute Percentage Error (MAPE).

    Parameters:
    y_true (array-like): True values.
    y_pred (array-like): Predicted values.

    Returns:
    float: The calculated MAPE.
    """
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ### 2. Load Dataset
# ---
# untuk training, kita akan coba pakai salah terlebih dahulu yaitu "Bawang Merah"

# %%
path = "/Users/Frederick/Documents/Datavidia/Harga Bahan Pangan"
files = [
    "Bawang Merah", "Bawang Putih Bonggol", "Beras Medium", "Beras Premium",
    "Cabai Merah Keriting", "Cabai Rawit Merah", "Daging Ayam Ras",
    "Daging Sapi Murni", "Gula Konsumsi", "Minyak Goreng Curah",
    "Minyak Goreng Kemasan Sederhana", "Telur Ayam Ras", "Tepung Terigu (Curah)"
]

# Load data
df_list = {}
for file in files:
    df = pd.read_csv(f"{path}/train/{file}.csv")
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index('Date')
    df_list[file] = df

# For Training purpose, we use only Bawang Merah since all training have the same approach
df = df_list["Bawang Merah"]
df.head()
# Out:
#                Aceh     Bali  ...  Sumatera Selatan  Sumatera Utara
# Date                          ...
# 2022-01-01  28970.0  20870.0  ...           26670.0         28710.0
# 2022-01-02  29900.0  20710.0  ...           25690.0         28460.0
# 2022-01-03  28970.0  20510.0  ...           26270.0         28050.0
# 2022-01-04  29600.0  20180.0  ...           26800.0         27800.0
# 2022-01-05  29540.0  19960.0  ...           25360.0         27670.0
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1004 entries, 2022-01-01 to 2024-09-30
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Aceh                       967 non-null    float64
#  1   Bali                       968 non-null    float64
#  2   Banten                     967 non-null    float64
#  3   Bengkulu                   967 non-null    float64
#  4   DI Yogyakarta              968 non-null    float64
#  5   DKI Jakarta                967 non-null    float64
#  6   Gorontalo                  969 non-null    float64
#  7   Jambi                      966 non-null    float64
#  8   Jawa Barat                 967 non-null    float64
#  9   Jawa Tengah                970 non-null    float64
#  10  Jawa Timur                 969 non-null    float64
#  11  Kalimantan Barat           968 non-null    float64
#  12  Kalimantan Selatan         967 non-null    float64
#  13  Kalimantan Tengah          968 non-null    float64
#  14  Kalimantan Timur           965 non-null    float64
#  15  Kalimantan Utara           965 non-null    float64
#  16  Kepulauan Bangka Belitung  966 non-null    float64
#  17  Kepulauan Riau             965 non-null    float64
#  18  Lampung                    967 non-null    float64
#  19  Maluku Utara               968 non-null    float64
#  20  Maluku                     967 non-null    float64
#  21  Nusa Tenggara Barat        967 non-null    float64
#  22  Nusa Tenggara Timur        970 non-null    float64
#  23  Papua Barat                965 non-null    float64
#  24  Papua                      967 non-null    float64
#  25  Riau                       969 non-null    float64
#  26  Sulawesi Barat             965 non-null    float64
#  27  Sulawesi Selatan           970 non-null    float64
#  28  Sulawesi Tengah            970 non-null    float64
#  29  Sulawesi Tenggara          968 non-null    float64
#  30  Sulawesi Utara             970 non-null    float64
#  31  Sumatera Barat             969 non-null    float64
#  32  Sumatera Selatan           966 non-null    float64
#  33  Sumatera Utara             968 non-null    float64
# dtypes: float64(34)
# memory usage: 274.5 KB

# %%
df.describe().T
# Out:
#                            count          mean  ...      75%      max
# Aceh                       967.0  34740.020683  ...  36660.0  61030.0
# Bali                       968.0  28202.200413  ...  30935.0  53400.0
# Banten                     967.0  34011.065150  ...  37285.0  68970.0
# Bengkulu                   967.0  34812.130300  ...  37750.0  61590.0
# DI Yogyakarta              968.0  30753.657025  ...  35450.0  61470.0
# DKI Jakarta                967.0  41475.170631  ...  44300.0  74630.0
# Gorontalo                  969.0  38127.925697  ...  42930.0  78300.0
# Jambi                      966.0  28944.668737  ...  31412.5  48820.0
# Jawa Barat                 967.0  33151.437435  ...  37020.0  65350.0
# Jawa Tengah                970.0  32025.659794  ...  36037.5  64100.0
# Jawa Timur                 969.0  30031.702786  ...  33690.0  63730.0
# Kalimantan Barat           968.0  36764.721074  ...  40132.5  67680.0
# Kalimantan Selatan         967.0  33281.013444  ...  37915.0  73700.0
# Kalimantan Tengah          968.0  37392.324380  ...  41200.0  73070.0
# Kalimantan Timur           965.0  37872.829016  ...  41290.0  79290.0
# Kalimantan Utara           965.0  42826.911917  ...  45150.0  78600.0
# Kepulauan Bangka Belitung  966.0  39795.351967  ...  44970.0  74870.0
# Kepulauan Riau             965.0  36388.538860  ...  38540.0  43460.0
# Lampung                    967.0  31832.812823  ...  37045.0  61900.0
# Maluku Utara               968.0  51948.512397  ...  54700.0  85520.0
# Maluku                     967.0  44022.771458  ...  47235.0  70990.0
# Nusa Tenggara Barat        967.0  28790.413650  ...  33810.0  53390.0
# Nusa Tenggara Timur        970.0  30641.134021  ...  36812.5  44270.0
# Papua Barat                965.0  53879.844560  ...  56810.0  80180.0
# Papua                      967.0  56483.588418  ...  59915.0  80580.0
# Riau                       969.0  33857.058824  ...  36560.0  51060.0
# Sulawesi Barat             965.0  33921.761658  ...  37740.0  72100.0
# Sulawesi Selatan           970.0  32272.938144  ...  35447.5  61080.0
# Sulawesi Tengah            970.0  38495.804124  ...  42190.0  74190.0
# Sulawesi Tenggara          968.0  38152.283058  ...  41520.0  68590.0
# Sulawesi Utara             970.0  41372.639175  ...  44357.5  74340.0
# Sumatera Barat             969.0  29558.513932  ...  32170.0  50350.0
# Sumatera Selatan           966.0  33948.768116  ...  37155.0  63140.0
# Sumatera Utara             968.0  33269.855372  ...  35030.0  55830.0
#
# [34 rows x 8 columns]

# %% [markdown]
# ### 3. Exploratory Data Analysis

# %%
df.plot(figsize=(15, 6))
plt.title('Harga Bawang Merah dalam 34 Provinsi di Indonesia')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan visualisasi yang kita lihat, harga bawang merah memiliki missing data pada Juli 2023. Sehingga kita akan coba melakukan sedikit pendekatan dengan melakukan interpolasi data untuk mengisi kekosongan data ini.

# %%
df.interpolate(method='linear', inplace=True)
df.bfill(inplace=True)
df.ffill(inplace=True)
df.plot(figsize=(15, 6))
plt.title('Harga Bawang Merah dalam 34 Provinsi di Indonesia')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Sekarang, coba kita rapikan visualisasinya dengan memperkecil range tanggal kita. Misal, dalam tahun waktu seminggu, kira-kira bagaimana fluktuasi harga bahan pangannya.

# %%
df_2024 = df[(df.index >= '2024-01-01') & (df.index <= '2024-01-31')]
df_2024.plot(figsize=(15, 6), lw = 4)
plt.title('Harga Bawang Merah dalam 34 Provinsi di Indonesia dari 1 Januari 2024 hingga 31 Januari 2024')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
plt.tight_layout()
plt.show()

# %%
# Take 'Aceh' data only for training only
df_aceh = df[['Aceh']]

plt.figure(figsize=(15, 6))
df_aceh.plot(style='.', 
             color='blue', 
             title='Harga Bawang Merah di Aceh')
plt.show()

# %% [markdown]
# ### 4. Data Preprocessing

# %% [markdown]
# > Outlier Removal

# %%
def clean_and_interpolate(df, column):
    """
    Membersihkan data dengan menghapus outlier dan menginterpolasi nilai kosong.
    """
    z_scores = np.abs(stats.zscore(df[column]))
    df[column] = pd.Series(np.where(z_scores > 3, np.nan, df[column]), index=df.index)
    df[column] = df[column].interpolate(method='linear').bfill().ffill()
    return df

# %% [markdown]
# > Stationary Check

# %%
def check_stationarity(df, column):
    """
    Melakukan uji ADF untuk mengecek stationary data.
    """
    adf_result = adfuller(df[column])
    p_value = adf_result[1]
    
    if p_value > 0.05:
        print(f'Data {column} non-stationary (p={p_value:.3f}), differencing diperlukan!')
        return False
    else:
        print(f'Data {column} sudah stationary (p={p_value:.3f}).')
        return True

# %% [markdown]
# > Melakukan differencing jika `check_stationarity(df, column)` = True

# %%
def difference(df, column):
    """
    Melakukan differencing pada data.
    """
    df[column] = df[column].diff()
    return df

# %% [markdown]
# > Melakukan uji seasonality

# %% [markdown]
# - **Apply preprocessing to our data:**

# %%
df_aceh = clean_and_interpolate(df_aceh, 'Aceh')
is_stationary = check_stationarity(df_aceh, 'Aceh')
# Out:
# Data Aceh sudah stationary (p=0.008).

# %% [markdown]
# ### 4. Train/Test Split

# %%
train_aceh = df_aceh.loc[df.index < '2024-01-01']
test_aceh = df_aceh.loc[df.index >= '2024-01-01']

fig, ax = plt.subplots(figsize=(15, 6))
train_aceh.plot(ax=ax, color='blue', style='.', lw=2)
test_aceh.plot(ax=ax, color='red', style='.', lw=2)
plt.title('Train/Test Split')
ax.axvline('01-01-2024', color='black', linestyle='--')
ax.legend(['Train Set', 'Test Set'])
plt.show()

# %% [markdown]
# ### 6. Modelling

# %% [markdown]
# - 6.1 Data Splitting

# %%
train_aceh = df_aceh.loc[df_aceh.index < '2024-01-01']
test_aceh = df_aceh.loc[df_aceh.index >= '2024-01-01']

# %% [markdown]
# - 6.2 Modelling
#
#     - **Arima Model**
#         - Inisialisasi model:
#             - `auto_arima()`:
#                 - parameter pertama adalah data training yang kurang lebih adalah label yang mau kita prediksi.
#                 - `seasonal` adalah parameter yang bersifat boolean yang menyatakan apakah data kita itu bersifat seasonality atau tidak.
#         - Training model:
#             - `.fit()`: menerima data training saja (data training yang diterima adalah data label tanpa adanya fitur tambahan)
#         - Attributes:
#             - `.order`: memberikan best `order` yang didapatkan untuk model ARIMA
#
#         - Methods:
#             - `.predict()`: memerlukan parameter **`n_periods`** yang menyatakan berapa banyak mau prediksi ke masa depan. Dia akan return sebuah series yang berisi prediksi ke masa depan sebesar `n_periods`

# %%
# Generate date untuk forecast steps setelah 31 Januari 2024
forecast_steps = len(test_aceh)

# Buat sebuah DataFrame kosong dengan index tanggal yang akan di forecast
forecast_dates = pd.date_range(start='2024-01-01',  # Awal mulai forecast
                               periods=forecast_steps, # Jumlah periode forecast (hari)
                               freq='D') # Frekuensi data harian, ubah ke 'D' untuk satuan hari, 'M' untuk satuan bulan, dst...

# %%
# Inisialisasi model ARIMA
model_ARIMA = auto_arima(   train_aceh["Aceh"], 
                            start_p=0, start_q=0,
                            max_p=3, max_q=3,
                            seasonal=True, 
                            stationary=is_stationary,
                            m = 7,
                            stepwise=True, 
                            suppress_warnings=True,
                            error_action='ignore', 
                            trace=True)

forecast_ARIMA = model_ARIMA.predict(n_periods=forecast_steps)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,0,1)[7] intercept   : AIC=14121.880, Time=0.83 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=14957.878, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=13438.473, Time=0.71 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=17334.896, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[7] intercept   : AIC=14038.597, Time=0.18 sec
#  ARIMA(0,0,1)(1,0,1)[7] intercept   : AIC=14315.910, Time=1.37 sec
#  ARIMA(0,0,1)(0,0,2)[7] intercept   : AIC=13022.097, Time=1.48 sec
#  ARIMA(0,0,1)(1,0,2)[7] intercept   : AIC=14287.204, Time=1.84 sec
#  ARIMA(0,0,0)(0,0,2)[7] intercept   : AIC=13649.286, Time=0.80 sec
#  ARIMA(1,0,1)(0,0,2)[7] intercept   : AIC=11389.933, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,1)[7] intercept   : AIC=11402.549, Time=0.29 sec
#  ARIMA(1,0,1)(1,0,2)[7] intercept   : AIC=11387.702, Time=1.75 sec
#  ARIMA(1,0,1)(1,0,1)[7] intercept   : AIC=11388.960, Time=1.25 sec
#  ARIMA(1,0,1)(2,0,2)[7] intercept   : AIC=11392.431, Time=2.32 sec
#  ARIMA(1,0,1)(2,0,1)[7] intercept   : AIC=11387.637, Time=2.08 sec
#  ARIMA(1,0,1)(2,0,0)[7] intercept   : AIC=11386.596, Time=1.66 sec
#  ARIMA(1,0,1)(1,0,0)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,0,1)(2,0,0)[7] intercept   : AIC=14436.202, Time=3.02 sec
#  ARIMA(1,0,0)(2,0,0)[7] intercept   : AIC=inf, Time=2.15 sec
#  ARIMA(2,0,1)(2,0,0)[7] intercept   : AIC=inf, Time=2.44 sec
#  ARIMA(1,0,2)(2,0,0)[7] intercept   : AIC=11384.802, Time=2.67 sec
#  ARIMA(1,0,2)(1,0,0)[7] intercept   : AIC=inf, Time=3.54 sec
#  ARIMA(1,0,2)(2,0,1)[7] intercept   : AIC=11387.267, Time=2.46 sec
#  ARIMA(1,0,2)(1,0,1)[7] intercept   : AIC=11390.434, Time=9.00 sec
#  ARIMA(0,0,2)(2,0,0)[7] intercept   : AIC=14394.394, Time=2.84 sec
#  ARIMA(2,0,2)(2,0,0)[7] intercept   : AIC=inf, Time=2.15 sec
#  ARIMA(1,0,3)(2,0,0)[7] intercept   : AIC=11387.273, Time=2.11 sec
#  ARIMA(0,0,3)(2,0,0)[7] intercept   : AIC=inf, Time=1.16 sec
#  ARIMA(2,0,3)(2,0,0)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,0,2)(2,0,0)[7]             : AIC=11392.277, Time=1.05 sec
#
# Best model:  ARIMA(1,0,2)(2,0,0)[7] intercept
# Total fit time: 55.354 seconds

# %%
model_ARIMA_manual = ARIMA(train_aceh["Aceh"], order=model_ARIMA.order)
model_ARIMA_manual_fit = model_ARIMA_manual.fit()

forecast_ARIMA_manual = model_ARIMA_manual_fit.get_forecast(steps=forecast_steps)
forecast_ARIMA_manual = forecast_ARIMA_manual.predicted_mean

fig, ax = plt.subplots(figsize=(15, 6))
train_aceh.plot(ax=ax, color='blue', style='.', lw=2)
test_aceh.plot(ax=ax, color='red', style='.', lw=2)
forecast_ARIMA_manual.plot(ax=ax, color='green', style='.', lw=2)
plt.title('ARIMA Manual Forecast')
ax.axvline('01-01-2024', color='black', linestyle='--')
ax.legend(['Train Set', 'Test Set', 'Forecast'])
plt.show()

# %% [markdown]
# ### 7. Evaluation

# %%
# Calculate MAPE
y_pred = forecast_ARIMA
y_test = test_aceh["Aceh"]

mape_ARIMA = mape(y_test, y_pred)
print(f'MAPE Score: {mape_ARIMA:.2f}%')
# Out:
# MAPE Score: 19.74%

# %%
# Calculate MAPE
y_pred_manual = forecast_ARIMA_manual
y_test = test_aceh["Aceh"]

mape_ARIMA_manual = mape(y_test, y_pred_manual)
print(f'MAPE Score Manual: {mape_ARIMA_manual:.2f}%')
# Out:
# MAPE Score Manual: 47.43%

# %% [markdown]
# **Conclusions**:
#     Dari sini kita tau kalau AUTO_ARIMA bekerja sedikit lebih baik ketimbang ARIMA

# %% [markdown]
# ---
# ### 8. Submissions

# %%
def train_predict_auto_arima_v2(df, province, komoditas='Tepung Terigu (Curah)',
                                cutoff_date='2024-10-01',
                                forecast_steps_default=92, save_plot=False):
    df = df.copy()

    # Preprocessing (clean & interpolate + cek stasioneritas)
    df_province = df[[province]]
    df_province = clean_and_interpolate(df_province, province)
    is_stationary = check_stationarity(df_province, province)

    ts = df_province.rename(columns={province: 'Price'})

    # Train-test split
    train = ts.loc[ts.index < cutoff_date]
    test = ts.loc[ts.index >= cutoff_date]

    # Forecasting dates
    forecast_steps = forecast_steps_default
    forecast_dates = pd.date_range(start=cutoff_date, periods=forecast_steps, freq='D')

    # Auto ARIMA (biar order otomatis)
    print(f"Training auto_arima untuk {komoditas} di {province} ...")
    stepwise_model = auto_arima(
        train['Price'],
        start_p=0, start_q=0,
        max_p=3, max_q=3,
        seasonal=False,
        stationary=is_stationary,
        m=7,
        trace=False,
        error_action='ignore',
        suppress_warnings=True,
        stepwise=True,
        information_criterion='aic',
        random_state=42
    )

    order = stepwise_model.order
    print(f"Best ARIMA order: {order}")

    # Build dan fit model ARIMA dari statsmodels
    model = ARIMA(train['Price'], order=order)
    model_fit = model.fit()

    # Forecast
    forecast_result = model_fit.get_forecast(steps=forecast_steps)
    forecast_mean = forecast_result.predicted_mean

    # Buat dataframe forecast untuk submission
    df_forecast = pd.DataFrame({
        'Date': forecast_dates,
        'price': forecast_mean.values
    })

    df_forecast['id'] = df_forecast['Date'].dt.strftime(f"{komoditas}/{province}/%Y-%m-%d")
    submission = df_forecast[['id', 'price']]

    # Hitung MAPE jika ada test data
    if len(test) > 0:
        test_actual = test['Price'].iloc[:forecast_steps]
        mape_val = mape(test_actual, forecast_mean)
    else:
        mape_val = None

    # Plot hasilnya
    if save_plot:
        plt.figure(figsize=(12, 6))
        plt.plot(train.index, train['Price'], label='Train', color='blue')
        plt.plot(test.index, test['Price'], label='Test', color='red')
        plt.plot(forecast_dates, forecast_mean, label='Forecast', color='green')
        plt.axvline(cutoff_date, color='black', linestyle='--')
        plt.title(f'Forecast {komoditas} di {province}')
        plt.legend()
        plt.show()

    return submission, mape_val, model_fit.summary(), order

# %%
all_final_submissions = []
all_mape = []
all_orders = []

for komoditas in files:
    print(f"Processing komoditas: {komoditas} ...")
    df_temp = df_list[komoditas]

    for prov in df_temp.columns.tolist():
        print(f" - Provinsi: {prov}")

        submission_prov, mape_val, model_summary, order = train_predict_auto_arima_v2(
            df_temp,
            province=prov,
            komoditas=komoditas,
            cutoff_date='2024-10-01',
            save_plot=False 
        )

        all_final_submissions.append(submission_prov)

        if mape_val is not None:
            all_mape.append({
                'Komoditas': komoditas,
                'Provinsi': prov,
                'MAPE': mape_val,
                'Order': order
            })

        print(model_summary)

# Gabungkan hasil submission
final_all_submission = pd.concat(all_final_submissions, ignore_index=True)
final_all_submission.to_csv("submission.csv", index=False)
# Out:
# Processing komoditas: Bawang Merah ...
#  - Provinsi: Aceh
# Data Aceh sudah stationary (p=0.008).
# Training auto_arima untuk Bawang Merah di Aceh ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -7926.010
# Date:                Sat, 15 Mar 2025   AIC                          15864.020
# Time:                        22:25:08   BIC                          15893.491
# Sample:                    01-01-2022   HQIC                         15875.219
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.541e+04   2231.752     15.868      0.000     3.1e+04    3.98e+04
# ar.L1          1.9644      0.011    180.205      0.000       1.943       1.986
# ar.L2         -0.9655      0.011    -89.624      0.000      -0.987      -0.944
# ma.L1         -1.0502      0.019    -55.947      0.000      -1.087      -1.013
# ma.L2          0.1569      0.015     10.284      0.000       0.127       0.187
# sigma2      4.189e+05     27.727   1.51e+04      0.000    4.19e+05    4.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              5632.36
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.50   Skew:                             0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.47e+19. Standard errors may be unstable.
#  - Provinsi: Bali
# Data Bali sudah stationary (p=0.013).
# Training auto_arima untuk Bawang Merah di Bali ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -7904.800
# Date:                Sat, 15 Mar 2025   AIC                          15821.599
# Time:                        22:25:15   BIC                          15851.070
# Sample:                    01-01-2022   HQIC                         15832.798
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.868e+04   1689.264     16.980      0.000    2.54e+04     3.2e+04
# ar.L1          1.9378      0.016    122.874      0.000       1.907       1.969
# ar.L2         -0.9397      0.016    -60.063      0.000      -0.970      -0.909
# ma.L1         -1.0096      0.027    -38.060      0.000      -1.062      -0.958
# ma.L2          0.1664      0.022      7.632      0.000       0.124       0.209
# sigma2      4.018e+05     18.568   2.16e+04      0.000    4.02e+05    4.02e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               713.59
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.87   Skew:                            -0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.51e+19. Standard errors may be unstable.
#  - Provinsi: Banten
# Data Banten sudah stationary (p=0.025).
# Training auto_arima untuk Bawang Merah di Banten ...
# Best ARIMA order: (3, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 2)   Log Likelihood               -8439.006
# Date:                Sat, 15 Mar 2025   AIC                          16892.012
# Time:                        22:25:21   BIC                          16926.394
# Sample:                    01-01-2022   HQIC                         16905.077
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.49e+04   2606.096     13.392      0.000    2.98e+04       4e+04
# ar.L1          1.8964      0.073     26.077      0.000       1.754       2.039
# ar.L2         -0.8929      0.139     -6.409      0.000      -1.166      -0.620
# ar.L3         -0.0059      0.068     -0.086      0.932      -0.140       0.128
# ma.L1         -1.1686      0.067    -17.556      0.000      -1.299      -1.038
# ma.L2          0.3375      0.061      5.554      0.000       0.218       0.457
# sigma2      1.165e+06     22.058   5.28e+04      0.000    1.17e+06    1.17e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               883.26
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.08e+20. Standard errors may be unstable.
#  - Provinsi: Bengkulu
# Data Bengkulu sudah stationary (p=0.019).
# Training auto_arima untuk Bawang Merah di Bengkulu ...
# Best ARIMA order: (3, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -7926.374
# Date:                Sat, 15 Mar 2025   AIC                          15864.748
# Time:                        22:25:28   BIC                          15894.219
# Sample:                    01-01-2022   HQIC                         15875.947
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.544e+04   2370.968     14.946      0.000    3.08e+04    4.01e+04
# ar.L1          1.7717      0.023     78.349      0.000       1.727       1.816
# ar.L2         -0.5884      0.036    -16.364      0.000      -0.659      -0.518
# ar.L3         -0.1845      0.015    -12.028      0.000      -0.215      -0.154
# ma.L1         -0.8724      0.019    -46.447      0.000      -0.909      -0.836
# sigma2      4.192e+05     59.408   7057.124      0.000    4.19e+05    4.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):              7341.96
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                            -0.02
# Prob(H) (two-sided):                  0.08   Kurtosis:                        16.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.21e+19. Standard errors may be unstable.
#  - Provinsi: DI Yogyakarta
# Data DI Yogyakarta sudah stationary (p=0.021).
# Training auto_arima untuk Bawang Merah di DI Yogyakarta ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -8275.967
# Date:                Sat, 15 Mar 2025   AIC                          16563.934
# Time:                        22:25:35   BIC                          16593.404
# Sample:                    01-01-2022   HQIC                         16575.133
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.155e+04   2031.603     15.531      0.000    2.76e+04    3.55e+04
# ar.L1          1.9603      0.015    130.589      0.000       1.931       1.990
# ar.L2         -0.9617      0.015    -64.725      0.000      -0.991      -0.933
# ma.L1         -1.1099      0.024    -45.867      0.000      -1.157      -1.062
# ma.L2          0.2013      0.022      9.146      0.000       0.158       0.244
# sigma2      8.417e+05     28.519   2.95e+04      0.000    8.42e+05    8.42e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              2186.56
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                             0.35
# Prob(H) (two-sided):                  0.42   Kurtosis:                        10.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.63e+19. Standard errors may be unstable.
#  - Provinsi: DKI Jakarta
# Data DKI Jakarta non-stationary (p=0.107), differencing diperlukan!
# Training auto_arima untuk Bawang Merah di DKI Jakarta ...
# Best ARIMA order: (0, 1, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8605.819
# Date:                Sat, 15 Mar 2025   AIC                          17215.639
# Time:                        22:25:36   BIC                          17225.460
# Sample:                    01-01-2022   HQIC                         17219.371
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1600      0.022     -7.426      0.000      -0.202      -0.118
# sigma2       1.66e+06   3.03e+04     54.744      0.000     1.6e+06    1.72e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              4284.24
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.62   Skew:                            -0.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Gorontalo
# Data Gorontalo sudah stationary (p=0.013).
# Training auto_arima untuk Bawang Merah di Gorontalo ...
# Best ARIMA order: (3, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -8567.221
# Date:                Sat, 15 Mar 2025   AIC                          17146.442
# Time:                        22:25:45   BIC                          17175.912
# Sample:                    01-01-2022   HQIC                         17157.641
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.875e+04   2569.821     15.080      0.000    3.37e+04    4.38e+04
# ar.L1          1.7534      0.065     26.914      0.000       1.626       1.881
# ar.L2         -0.6371      0.086     -7.369      0.000      -0.807      -0.468
# ar.L3         -0.1193      0.027     -4.373      0.000      -0.173      -0.066
# ma.L1         -0.8010      0.063    -12.770      0.000      -0.924      -0.678
# sigma2      1.505e+06     23.480   6.41e+04      0.000     1.5e+06     1.5e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              7507.42
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.51   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.85e+19. Standard errors may be unstable.
#  - Provinsi: Jambi
# Data Jambi sudah stationary (p=0.011).
# Training auto_arima untuk Bawang Merah di Jambi ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -7709.797
# Date:                Sat, 15 Mar 2025   AIC                          15431.594
# Time:                        22:25:53   BIC                          15461.064
# Sample:                    01-01-2022   HQIC                         15442.792
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.956e+04   1966.557     15.033      0.000    2.57e+04    3.34e+04
# ar.L1          1.9641      0.015    132.040      0.000       1.935       1.993
# ar.L2         -0.9651      0.015    -65.050      0.000      -0.994      -0.936
# ma.L1         -0.9068      0.028    -32.260      0.000      -0.962      -0.852
# ma.L2          0.0130      0.022      0.590      0.555      -0.030       0.056
# sigma2      2.723e+05     81.582   3338.204      0.000    2.72e+05    2.72e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              3237.31
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.33   Skew:                             0.26
# Prob(H) (two-sided):                  0.01   Kurtosis:                        11.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.06e+22. Standard errors may be unstable.
#  - Provinsi: Jawa Barat
# Data Jawa Barat sudah stationary (p=0.013).
# Training auto_arima untuk Bawang Merah di Jawa Barat ...
# Best ARIMA order: (2, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 1)   Log Likelihood               -7848.733
# Date:                Sat, 15 Mar 2025   AIC                          15707.465
# Time:                        22:25:59   BIC                          15732.024
# Sample:                    01-01-2022   HQIC                         15716.797
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.384e+04   2263.823     14.947      0.000    2.94e+04    3.83e+04
# ar.L1          1.9412      0.011    175.542      0.000       1.919       1.963
# ar.L2         -0.9429      0.011    -85.279      0.000      -0.965      -0.921
# ma.L1         -0.8250      0.018    -46.106      0.000      -0.860      -0.790
# sigma2      3.592e+05     98.343   3652.464      0.000    3.59e+05    3.59e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.94   Jarque-Bera (JB):              2549.52
# Prob(Q):                              0.33   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.49   Skew:                            -0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.56e+23. Standard errors may be unstable.
#  - Provinsi: Jawa Tengah
# Data Jawa Tengah sudah stationary (p=0.007).
# Training auto_arima untuk Bawang Merah di Jawa Tengah ...
# Best ARIMA order: (2, 0, 3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 3)   Log Likelihood               -8290.068
# Date:                Sat, 15 Mar 2025   AIC                          16594.136
# Time:                        22:26:13   BIC                          16628.518
# Sample:                    01-01-2022   HQIC                         16607.201
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.272e+04   3615.338      9.050      0.000    2.56e+04    3.98e+04
# ar.L1          1.9111      0.018    108.487      0.000       1.877       1.946
# ar.L2         -0.9132      0.018    -52.177      0.000      -0.948      -0.879
# ma.L1         -0.9962      0.017    -57.426      0.000      -1.030      -0.962
# ma.L2         -0.0554      0.012     -4.470      0.000      -0.080      -0.031
# ma.L3          0.2199      0.008     26.374      0.000       0.204       0.236
# sigma2      8.894e+05    121.809   7301.839      0.000    8.89e+05     8.9e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):            384057.01
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.60   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                        98.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.6e+18. Standard errors may be unstable.
#  - Provinsi: Jawa Timur
# Data Jawa Timur sudah stationary (p=0.007).
# Training auto_arima untuk Bawang Merah di Jawa Timur ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -7651.364
# Date:                Sat, 15 Mar 2025   AIC                          15314.728
# Time:                        22:26:22   BIC                          15344.199
# Sample:                    01-01-2022   HQIC                         15325.927
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.068e+04   2465.879     12.443      0.000    2.59e+04    3.55e+04
# ar.L1          1.9158      0.011    174.420      0.000       1.894       1.937
# ar.L2         -0.9180      0.011    -84.421      0.000      -0.939      -0.897
# ma.L1         -0.9574      0.021    -44.542      0.000      -1.000      -0.915
# ma.L2          0.2673      0.019     13.846      0.000       0.229       0.305
# sigma2      2.422e+05   6778.056     35.731      0.000    2.29e+05    2.55e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1091.87
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.94   Skew:                            -0.61
# Prob(H) (two-sided):                  0.54   Kurtosis:                         7.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Kalimantan Barat
# Data Kalimantan Barat sudah stationary (p=0.004).
# Training auto_arima untuk Bawang Merah di Kalimantan Barat ...
# Best ARIMA order: (3, 0, 3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 3)   Log Likelihood               -7687.459
# Date:                Sat, 15 Mar 2025   AIC                          15390.918
# Time:                        22:26:33   BIC                          15430.212
# Sample:                    01-01-2022   HQIC                         15405.849
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.724e+04   1490.581     24.981      0.000    3.43e+04    4.02e+04
# ar.L1          0.9765      0.013     75.981      0.000       0.951       1.002
# ar.L2          0.9847      0.009    104.402      0.000       0.966       1.003
# ar.L3         -0.9636      0.012    -79.247      0.000      -0.987      -0.940
# ma.L1         -0.1255      0.040     -3.112      0.002      -0.205      -0.046
# ma.L2         -0.8885      0.028    -31.271      0.000      -0.944      -0.833
# ma.L3          0.2369      0.023     10.093      0.000       0.191       0.283
# sigma2      2.652e+05      0.538   4.93e+05      0.000    2.65e+05    2.65e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):              2377.77
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.28   Skew:                            -0.05
# Prob(H) (two-sided):                  0.02   Kurtosis:                        10.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.95e+22. Standard errors may be unstable.
#  - Provinsi: Kalimantan Selatan
# Data Kalimantan Selatan sudah stationary (p=0.007).
# Training auto_arima untuk Bawang Merah di Kalimantan Selatan ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -8061.328
# Date:                Sat, 15 Mar 2025   AIC                          16134.657
# Time:                        22:26:40   BIC                          16164.127
# Sample:                    01-01-2022   HQIC                         16145.855
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.381e+04   2192.893     15.419      0.000    2.95e+04    3.81e+04
# ar.L1          1.9281      0.017    115.241      0.000       1.895       1.961
# ar.L2         -0.9301      0.017    -55.971      0.000      -0.963      -0.898
# ma.L1         -0.9862      0.024    -40.813      0.000      -1.034      -0.939
# ma.L2          0.1721      0.017     10.230      0.000       0.139       0.205
# sigma2      5.486e+05     74.419   7372.399      0.000    5.49e+05    5.49e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1702.38
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.40   Skew:                             0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.02e+22. Standard errors may be unstable.
#  - Provinsi: Kalimantan Tengah
# Data Kalimantan Tengah sudah stationary (p=0.012).
# Training auto_arima untuk Bawang Merah di Kalimantan Tengah ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -7863.589
# Date:                Sat, 15 Mar 2025   AIC                          15739.179
# Time:                        22:26:48   BIC                          15768.649
# Sample:                    01-01-2022   HQIC                         15750.377
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.791e+04   2327.040     16.290      0.000    3.33e+04    4.25e+04
# ar.L1          1.9412      0.018    108.052      0.000       1.906       1.976
# ar.L2         -0.9428      0.018    -52.876      0.000      -0.978      -0.908
# ma.L1         -1.1388      0.025    -46.478      0.000      -1.187      -1.091
# ma.L2          0.3033      0.015     20.402      0.000       0.274       0.332
# sigma2      3.699e+05   5316.593     69.577      0.000    3.59e+05     3.8e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):            144009.27
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.48   Skew:                             3.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                        61.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Kalimantan Timur
# Data Kalimantan Timur sudah stationary (p=0.001).
# Training auto_arima untuk Bawang Merah di Kalimantan Timur ...
# Best ARIMA order: (3, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -8513.107
# Date:                Sat, 15 Mar 2025   AIC                          17038.214
# Time:                        22:26:52   BIC                          17067.684
# Sample:                    01-01-2022   HQIC                         17049.412
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.828e+04   3413.083     11.217      0.000    3.16e+04     4.5e+04
# ar.L1         -0.1379      0.119     -1.159      0.247      -0.371       0.095
# ar.L2          0.8058      0.090      8.908      0.000       0.629       0.983
# ar.L3          0.3169      0.034      9.249      0.000       0.250       0.384
# ma.L1          0.7864      0.124      6.317      0.000       0.542       1.030
# sigma2       1.36e+06   3.96e+04     34.357      0.000    1.28e+06    1.44e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               593.27
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                             0.05
# Prob(H) (two-sided):                  0.24   Kurtosis:                         6.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Kalimantan Utara
# Data Kalimantan Utara sudah stationary (p=0.018).
# Training auto_arima untuk Bawang Merah di Kalimantan Utara ...
# Best ARIMA order: (2, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 2)   Log Likelihood               -8340.169
# Date:                Sat, 15 Mar 2025   AIC                          16692.339
# Time:                        22:26:58   BIC                          16721.809
# Sample:                    01-01-2022   HQIC                         16703.537
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.315e+04   1841.463     23.434      0.000    3.95e+04    4.68e+04
# ar.L1          1.9697      0.010    204.438      0.000       1.951       1.989
# ar.L2         -0.9709      0.010   -100.729      0.000      -0.990      -0.952
# ma.L1         -1.3581      0.015    -90.059      0.000      -1.388      -1.329
# ma.L2          0.4189      0.014     29.467      0.000       0.391       0.447
# sigma2      9.566e+05     17.210   5.56e+04      0.000    9.57e+05    9.57e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):             47941.37
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.61   Skew:                            -2.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.16e+22. Standard errors may be unstable.
#  - Provinsi: Kepulauan Bangka Belitung
# Data Kepulauan Bangka Belitung sudah stationary (p=0.031).
# Training auto_arima untuk Bawang Merah di Kepulauan Bangka Belitung ...
# Best ARIMA order: (3, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 1)   Log Likelihood               -8404.723
# Date:                Sat, 15 Mar 2025   AIC                          16821.445
# Time:                        22:27:03   BIC                          16850.916
# Sample:                    01-01-2022   HQIC                         16832.644
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.054e+04   2311.902     17.535      0.000     3.6e+04    4.51e+04
# ar.L1          1.7635      0.027     65.916      0.000       1.711       1.816
# ar.L2         -0.5689      0.045    -12.715      0.000      -0.657      -0.481
# ar.L3         -0.1959      0.021     -9.296      0.000      -0.237      -0.155
# ma.L1         -0.9136      0.023    -39.222      0.000      -0.959      -0.868
# sigma2      1.088e+06     49.693   2.19e+04      0.000    1.09e+06    1.09e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              1708.84
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             0.65
# Prob(H) (two-sided):                  0.37   Kurtosis:                         9.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.28e+23. Standard errors may be unstable.
#  - Provinsi: Kepulauan Riau
# Data Kepulauan Riau non-stationary (p=0.078), differencing diperlukan!
# Training auto_arima untuk Bawang Merah di Kepulauan Riau ...
# Best ARIMA order: (1, 1, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -8534.591
# Date:                Sat, 15 Mar 2025   AIC                          17075.183
# Time:                        22:27:07   BIC                          17089.915
# Sample:                    01-01-2022   HQIC                         17080.781
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1433      0.022      6.510      0.000       0.100       0.186
# ma.L1         -0.6545      0.027    -24.041      0.000      -0.708      -0.601
# sigma2      1.312e+06   4.41e+04     29.744      0.000    1.23e+06     1.4e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.92   Jarque-Bera (JB):              1638.65
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.63   Skew:                             0.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Lampung
# Data Lampung sudah stationary (p=0.041).
# Training auto_arima untuk Bawang Merah di Lampung ...
# Best ARIMA order: (2, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 1)   Log Likelihood               -8175.932
# Date:                Sat, 15 Mar 2025   AIC                          16361.863
# Time:                        22:27:13   BIC                          16386.422
# Sample:                    01-01-2022   HQIC                         16371.195
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.26e+04   2781.154     11.720      0.000    2.71e+04     3.8e+04
# ar.L1          1.9534      0.013    145.496      0.000       1.927       1.980
# ar.L2         -0.9546      0.013    -71.870      0.000      -0.981      -0.929
# ma.L1         -0.8916      0.016    -57.455      0.000      -0.922      -0.861
# sigma2      6.896e+05    389.795   1769.137      0.000    6.89e+05     6.9e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):             49116.81
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.11   Skew:                             2.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                        37.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.74e+17. Standard errors may be unstable.
#  - Provinsi: Maluku Utara
# Data Maluku Utara sudah stationary (p=0.026).
# Training auto_arima untuk Bawang Merah di Maluku Utara ...
# Best ARIMA order: (2, 0, 3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 0, 3)   Log Likelihood               -8598.582
# Date:                Sat, 15 Mar 2025   AIC                          17211.164
# Time:                        22:27:23   BIC                          17245.547
# Sample:                    01-01-2022   HQIC                         17224.229
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.238e+04   1858.474     28.186      0.000    4.87e+04     5.6e+04
# ar.L1          1.9677      0.017    114.055      0.000       1.934       2.002
# ar.L2         -0.9687      0.017    -56.947      0.000      -1.002      -0.935
# ma.L1         -1.3881      0.027    -50.722      0.000      -1.442      -1.334
# ma.L2          0.4541      0.041     11.155      0.000       0.374       0.534
# ma.L3         -0.0217      0.027     -0.790      0.430      -0.075       0.032
# sigma2      1.644e+06      6.853    2.4e+05      0.000    1.64e+06    1.64e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               487.00
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.52   Skew:                            -0.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.87e+20. Standard errors may be unstable.
#  - Provinsi: Maluku
# Data Maluku sudah stationary (p=0.007).
# Training auto_arima untuk Bawang Merah di Maluku ...
# Best ARIMA order: (3, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 0, 2)   Log Likelihood               -8529.207
# Date:                Sat, 15 Mar 2025   AIC                          17072.413
# Time:                        22:27:34   BIC                          17106.795
# Sample:                    01-01-2022   HQIC                         17085.478
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.444e+04   1725.221     25.759      0.000    4.11e+04    4.78e+04
# ar.L1          2.1181      0.058     36.775      0.000       2.005       2.231
# ar.L2         -1.2716      0.114    -11.169      0.000      -1.495      -1.048
# ar.L3          0.1525      0.057      2.664      0.008       0.040       0.265
# ma.L1         -1.5557      0.050    -31.267      0.000      -1.653      -1.458
# ma.L2          0.6007      0.050     12.090      0.000       0.503       0.698
# sigma2       1.44e+06      2.763   5.21e+05      0.000    1.44e+06    1.44e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               157.37
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.22   Skew:                            -0.14
# Prob(H) (two-sided):                  0.07   Kurtosis:                         4.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.35e+21. Standard errors may be unstable.
#  - Provinsi: Nusa Tenggara Barat
# Data Nusa Tenggara Barat non-stationary (p=0.081), differencing diperlukan!
# Training auto_arima untuk Bawang Merah di Nusa Tenggara Barat ...
# Best ARIMA order: (2, 1, 0)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# ...
# Time:                        23:19:14   BIC                          12066.959
# Sample:                    01-01-2022   HQIC                         12060.869
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6330      0.014    -45.692      0.000      -0.660      -0.606
# sigma2      9680.8024    119.233     81.192      0.000    9447.109    9914.495
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             26283.49
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.83   Skew:                             2.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sulawesi Selatan
# Data Sulawesi Selatan sudah stationary (p=0.028).
# Training auto_arima untuk Tepung Terigu (Curah) di Sulawesi Selatan ...
# Best ARIMA order: (1, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(1, 0, 2)   Log Likelihood               -5941.859
# Date:                Sat, 15 Mar 2025   AIC                          11893.718
# Time:                        23:19:26   BIC                          11918.277
# Sample:                    01-01-2022   HQIC                         11903.050
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9502.6175   1684.610      5.641      0.000    6200.843    1.28e+04
# ar.L1          0.9996      0.001    790.257      0.000       0.997       1.002
# ma.L1         -0.5385      0.008    -64.020      0.000      -0.555      -0.522
# ma.L2         -0.1631      0.010    -16.543      0.000      -0.182      -0.144
# sigma2      8047.1960     73.253    109.854      0.000    7903.622    8190.770
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):            103401.36
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.90   Skew:                             3.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        52.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sulawesi Tengah
# Data Sulawesi Tengah non-stationary (p=0.142), differencing diperlukan!
# Training auto_arima untuk Tepung Terigu (Curah) di Sulawesi Tengah ...
# Best ARIMA order: (2, 1, 3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 1, 3)   Log Likelihood               -6411.405
# Date:                Sat, 15 Mar 2025   AIC                          12834.811
# Time:                        23:19:35   BIC                          12864.275
# Sample:                    01-01-2022   HQIC                         12846.008
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5126      0.054     -9.412      0.000      -0.619      -0.406
# ar.L2         -0.8998      0.052    -17.198      0.000      -1.002      -0.797
# ma.L1         -0.1480      0.056     -2.632      0.009      -0.258      -0.038
# ma.L2          0.4891      0.064      7.607      0.000       0.363       0.615
# ma.L3         -0.6285      0.039    -16.295      0.000      -0.704      -0.553
# sigma2      2.101e+04    311.639     67.424      0.000    2.04e+04    2.16e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             13198.47
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.28   Skew:                            -0.33
# Prob(H) (two-sided):                  0.02   Kurtosis:                        20.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sulawesi Tenggara
# Data Sulawesi Tenggara non-stationary (p=0.791), differencing diperlukan!
# Training auto_arima untuk Tepung Terigu (Curah) di Sulawesi Tenggara ...
# Best ARIMA order: (2, 1, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -6363.137
# Date:                Sat, 15 Mar 2025   AIC                          12734.275
# Time:                        23:19:39   BIC                          12753.918
# Sample:                    01-01-2022   HQIC                         12741.740
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0116      0.051     -0.230      0.818      -0.111       0.088
# ar.L2          0.1826      0.036      5.055      0.000       0.112       0.253
# ma.L1         -0.7364      0.042    -17.350      0.000      -0.820      -0.653
# sigma2      1.886e+04    492.971     38.264      0.000    1.79e+04    1.98e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               900.84
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.75   Skew:                            -0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sulawesi Utara
# Data Sulawesi Utara non-stationary (p=0.316), differencing diperlukan!
# Training auto_arima untuk Tepung Terigu (Curah) di Sulawesi Utara ...
# Best ARIMA order: (3, 2, 0)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(3, 2, 0)   Log Likelihood               -6249.073
# Date:                Sat, 15 Mar 2025   AIC                          12506.146
# Time:                        23:19:41   BIC                          12525.785
# Sample:                    01-01-2022   HQIC                         12513.609
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.0835      0.015    -74.572      0.000      -1.112      -1.055
# ar.L2         -0.8068      0.021    -38.878      0.000      -0.848      -0.766
# ar.L3         -0.3742      0.020    -18.394      0.000      -0.414      -0.334
# sigma2      1.531e+04    312.477     48.986      0.000    1.47e+04    1.59e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.68   Jarque-Bera (JB):              3731.45
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.45   Skew:                            -0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sumatera Barat
# Data Sumatera Barat sudah stationary (p=0.039).
# Training auto_arima untuk Tepung Terigu (Curah) di Sumatera Barat ...
# Best ARIMA order: (1, 0, 2)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(1, 0, 2)   Log Likelihood               -6408.961
# Date:                Sat, 15 Mar 2025   AIC                          12827.921
# Time:                        23:19:53   BIC                          12852.480
# Sample:                    01-01-2022   HQIC                         12837.254
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.041e+04   2783.272      3.740      0.000    4952.973    1.59e+04
# ar.L1          0.9997      0.001    852.758      0.000       0.997       1.002
# ma.L1         -0.6118      0.019    -31.685      0.000      -0.650      -0.574
# ma.L2         -0.1656      0.017    -10.012      0.000      -0.198      -0.133
# sigma2      2.041e+04    149.084    136.935      0.000    2.01e+04    2.07e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):            284571.93
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.67   Skew:                             5.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                        84.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sumatera Selatan
# Data Sumatera Selatan sudah stationary (p=0.027).
# Training auto_arima untuk Tepung Terigu (Curah) di Sumatera Selatan ...
# Best ARIMA order: (1, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -5568.704
# Date:                Sat, 15 Mar 2025   AIC                          11145.407
# Time:                        23:19:58   BIC                          11165.054
# Sample:                    01-01-2022   HQIC                         11152.873
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9800.1021   1943.364      5.043      0.000    5991.178    1.36e+04
# ar.L1          0.9997      0.001    821.090      0.000       0.997       1.002
# ma.L1         -0.4959      0.016    -30.818      0.000      -0.527      -0.464
# sigma2      3823.2387     68.313     55.966      0.000    3689.347    3957.130
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):              4606.32
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                             0.34
# Prob(H) (two-sided):                  0.32   Kurtosis:                        13.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#  - Provinsi: Sumatera Utara
# Data Sumatera Utara sudah stationary (p=0.024).
# Training auto_arima untuk Tepung Terigu (Curah) di Sumatera Utara ...
# Best ARIMA order: (1, 0, 1)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1004
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -5997.507
# Date:                Sat, 15 Mar 2025   AIC                          12003.013
# Time:                        23:20:03   BIC                          12022.660
# Sample:                    01-01-2022   HQIC                         12010.479
#                          - 09-30-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.033e+04   1775.801      5.817      0.000    6849.874    1.38e+04
# ar.L1          0.9997      0.001    907.295      0.000       0.998       1.002
# ma.L1         -0.7107      0.014    -51.993      0.000      -0.737      -0.684
# sigma2      8989.2995    170.901     52.600      0.000    8654.340    9324.259
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              5037.56
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.17   Skew:                             1.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
